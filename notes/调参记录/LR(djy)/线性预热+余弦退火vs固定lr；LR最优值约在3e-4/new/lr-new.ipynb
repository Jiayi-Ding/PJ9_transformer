# %%
# 列出上传的数据集目录以确认路径
# !ls /kaggle/input/datasets/kingyaoxing/lr-new-68
# Out:
# boundaries_train_5.pt  model.py		 rhyme_dict.json    train_data_5.pt
# boundaries_train_7.pt  pingze_dict.json  rhyme_utils.py     train_data_7.pt
# boundaries_val_5.pt    poetry_5.txt	 topics_train_5.pt  train.py
# boundaries_val_7.pt    poetry_7.txt	 topics_train_7.pt  val_data_5.pt
# build_pingze_dict.py   poetry.txt	 topics_val_5.pt    val_data_7.pt
# build_rhyme_dict.py    predict.py	 topics_val_7.pt    vocab.json
# dataset.py	       prepare_data.py	 topic_vocab.json

# %%
# 1. 直接复制输入目录中的代码到工作目录
# !mkdir -p /kaggle/working/project
# !cp -r /kaggle/input/datasets/kingyaoxing/lr-new-68/* /kaggle/working/project/

# 2. 进入项目目录
import os
os.chdir("/kaggle/working/project")

# %%
# !python train.py --genre 5 --use_topic --epochs 20 --batch_size 32 --lr 3e-4 \
  --save /kaggle/working/ckpt_best_5-2.pt \
  --log_plot /kaggle/working/loss_curve_5-2.png \
  2>&1 | tee /kaggle/working/training_log_5-2-new.txt
# Out:
# 选定体裁: 5
# 启用主题: True
# 训练数据: train_data_5.pt, 验证数据: val_data_5.pt
# 保存模型: /kaggle/working/ckpt_best_5-2.pt
# 设备: cuda
# 主题数量: 19, 主题列表: ['landscape', 'frontier', 'homesickness', 'historical', 'love', 'objects', 'farewell', 'time_sorrow', 'festival', 'palace_grievance', 'immortal', 'zen', 'drinking', 'elegy', 'imperial_exam', 'war_atrocity', 'feminine_life', 'reclusion_tourism', 'other']
# 正在加载训练/验证张量...
# 已加载主题和边界: 65510 首诗，序列长度 2929258
# 已加载主题和边界: 7279 首诗，序列长度 325620
# 正在使用 torch.compile 编译模型（首次编译耗时较长）...
# torch.compile 编译完成
# W0608 18:09:26.663000 89 torch/_inductor/utils.py:1679] [0/0] Not enough SMs to use max_autotune_gemm mode
#   epoch 1 step 50 loss 8.5560 lr=1.22e-05
#   epoch 1 step 100 loss 8.2872 lr=1.27e-05
#   epoch 1 step 150 loss 8.0888 lr=1.36e-05
#   epoch 1 step 200 loss 7.8607 lr=1.49e-05
#   epoch 1 step 250 loss 7.6369 lr=1.65e-05
#   epoch 1 step 300 loss 7.4113 lr=1.85e-05
#   epoch 1 step 350 loss 7.1450 lr=2.08e-05
# ...

# %%
# !python train.py --genre 5 --use_topic --epochs 20 --batch_size 32 --lr 5e-4 \
  --save /kaggle/working/ckpt_best_5-3.pt \
  --log_plot /kaggle/working/loss_curve_5-3.png \
  2>&1 | tee /kaggle/working/training_log_5-3-new.txt
# Out:
# 选定体裁: 5
# 启用主题: True
# 训练数据: train_data_5.pt, 验证数据: val_data_5.pt
# 保存模型: /kaggle/working/ckpt_best_5-3.pt
# 设备: cuda
# 主题数量: 19, 主题列表: ['landscape', 'frontier', 'homesickness', 'historical', 'love', 'objects', 'farewell', 'time_sorrow', 'festival', 'palace_grievance', 'immortal', 'zen', 'drinking', 'elegy', 'imperial_exam', 'war_atrocity', 'feminine_life', 'reclusion_tourism', 'other']
# 正在加载训练/验证张量...
# 已加载主题和边界: 65510 首诗，序列长度 2929258
# 已加载主题和边界: 7279 首诗，序列长度 325620
# 正在使用 torch.compile 编译模型（首次编译耗时较长）...
# torch.compile 编译完成
#   epoch 1 step 50 loss 8.3852 lr=2.03e-05
#   epoch 1 step 100 loss 8.0596 lr=2.12e-05
#   epoch 1 step 150 loss 7.7563 lr=2.27e-05
#   epoch 1 step 200 loss 7.4180 lr=2.48e-05
#   epoch 1 step 250 loss 7.0986 lr=2.75e-05
#   epoch 1 step 300 loss 6.8838 lr=3.08e-05
#   epoch 1 step 350 loss 6.6295 lr=3.47e-05
#   epoch 1 step 400 loss 6.5124 lr=3.92e-05
#   epoch 1 step 450 loss 6.4571 lr=4.42e-05
#   epoch 1 step 500 loss 6.3310 lr=4.97e-05
# ...

# %%
# !python train.py --genre 5 --use_topic --epochs 20 --batch_size 32 --lr 1e-3 \
  --save /kaggle/working/ckpt_best_5-4.pt \
  --log_plot /kaggle/working/loss_curve_5-4.png \
  2>&1 | tee /kaggle/working/training_log_5-4-new.txt
# Out:
# 选定体裁: 5
# 启用主题: True
# 训练数据: train_data_5.pt, 验证数据: val_data_5.pt
# 保存模型: /kaggle/working/ckpt_best_5-4.pt
# 设备: cuda
# 主题数量: 19, 主题列表: ['landscape', 'frontier', 'homesickness', 'historical', 'love', 'objects', 'farewell', 'time_sorrow', 'festival', 'palace_grievance', 'immortal', 'zen', 'drinking', 'elegy', 'imperial_exam', 'war_atrocity', 'feminine_life', 'reclusion_tourism', 'other']
# 正在加载训练/验证张量...
# 已加载主题和边界: 65510 首诗，序列长度 2929258
# 已加载主题和边界: 7279 首诗，序列长度 325620
# 正在使用 torch.compile 编译模型（首次编译耗时较长）...
# torch.compile 编译完成
#   epoch 1 step 50 loss 8.1113 lr=4.06e-05
#   epoch 1 step 100 loss 7.5498 lr=4.24e-05
#   epoch 1 step 150 loss 7.0630 lr=4.55e-05
#   epoch 1 step 200 loss 6.6661 lr=4.97e-05
#   epoch 1 step 250 loss 6.4727 lr=5.51e-05
#   epoch 1 step 300 loss 6.4175 lr=6.17e-05
#   epoch 1 step 350 loss 6.2870 lr=6.94e-05
#   epoch 1 step 400 loss 6.2871 lr=7.83e-05
#   epoch 1 step 450 loss 6.2848 lr=8.83e-05
#   epoch 1 step 500 loss 6.1659 lr=9.94e-05
# ...
